# %% [markdown]
# <a href="https://colab.research.google.com/github/hideaki-kyutech/test/blob/master/06_softcomputing_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
# make the original data
N = 1000
series = np.sin(0.1*np.arange(N)) #+ np.random.randn(N)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y).reshape(-1, 1)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (990, 10, 1) Y.shape (990, 1)

# %%
# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
### Define simple RNN
class SimpleRNN(nn.Module):
  def __init__(self, n_inputs, n_hidden, n_rnnlayers, n_outputs):
    super(SimpleRNN, self).__init__()
    self.D = n_inputs
    self.M = n_hidden
    self.K = n_outputs
    self.L = n_rnnlayers

    # note: batch_first=True
    # applies the convention that our data will be of shape:
    # (num_samples, sequence_length, num_features)
    # rather than:
    # (sequence_length, num_samples, num_features)
    self.rnn = nn.RNN(
        input_size=self.D,
        hidden_size=self.M,
        num_layers=self.L,
        nonlinearity='relu',
        batch_first=True)
    self.fc = nn.Linear(self.M, self.K)
  
  def forward(self, X):
    # initial hidden states
    h0 = torch.zeros(self.L, X.size(0), self.M).to(device)

    # get RNN unit output
    # out is of size (N, T, M)
    # 2nd return value is hidden states at each hidden layer
    # we don't need those now
    out, _ = self.rnn(X, h0)

    # we only want h(T) at the final time step
    # N x M -> N x K
    out = self.fc(out[:, -1, :])
    return out

# %%
# Instantiate the model
model = SimpleRNN(n_inputs=1, n_hidden=15, n_rnnlayers=1, n_outputs=1)
model.to(device)
# Out:
# SimpleRNN(
#   (rnn): RNN(1, 15, batch_first=True)
#   (fc): Linear(in_features=15, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Make inputs and targets
X_train = torch.from_numpy(X[:-N//2].astype(np.float32))
y_train = torch.from_numpy(Y[:-N//2].astype(np.float32))
X_test = torch.from_numpy(X[-N//2:].astype(np.float32))
y_test = torch.from_numpy(Y[-N//2:].astype(np.float32))

# %%
# move data to GPU
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
# Training
def full_gd(model,
            criterion,
            optimizer,
            X_train,
            y_train,
            X_test,
            y_test,
            epochs=1000):

  # Stuff to store
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    # zero the parameter gradients
    optimizer.zero_grad()

    # Forward pass
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
      
    # Backward and optimize
    loss.backward()
    optimizer.step()

    # Save losses
    train_losses[it] = loss.item()

    # Test loss
    test_outputs = model(X_test)
    test_loss = criterion(test_outputs, y_test)
    test_losses[it] = test_loss.item()
      
    if (it + 1) % 5 == 0:
      print(f'Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, Test Loss: {test_loss.item():.4f}')
  
  return train_losses, test_losses

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test)
# Out:
# Epoch 5/1000, Train Loss: 0.5434, Test Loss: 0.5452
# Epoch 10/1000, Train Loss: 0.5147, Test Loss: 0.5163
# Epoch 15/1000, Train Loss: 0.4880, Test Loss: 0.4898
# Epoch 20/1000, Train Loss: 0.4647, Test Loss: 0.4667
# Epoch 25/1000, Train Loss: 0.4440, Test Loss: 0.4458
# Epoch 275/1000, Train Loss: 0.0004, Test Loss: 0.0004
# Epoch 280/1000, Train Loss: 0.0004, Test Loss: 0.0004
# Epoch 285/1000, Train Loss: 0.0004, Test Loss: 0.0003
# Epoch 290/1000, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 295/1000, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 300/1000, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 305/1000, Train Loss: 0.0003, Test Loss: 0.0003
# Epoch 310/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 315/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 320/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 325/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 330/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 335/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 340/1000, Train Loss: 0.0002, Test Loss: 0.0002
# Epoch 345/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 350/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 355/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 360/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 365/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 370/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 375/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 380/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 385/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 390/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 395/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 400/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 405/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 410/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 415/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 420/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 425/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 430/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 435/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 440/1000, Train Loss: 0.0001, Test Loss: 0.0001
# Epoch 445/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 450/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 455/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 460/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 465/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 470/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 475/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 480/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 485/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 490/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 495/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 500/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 505/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 510/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 515/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 520/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 525/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 530/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 535/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 540/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 545/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 550/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 555/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 560/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 565/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 570/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 575/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 580/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 585/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 590/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 595/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 600/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 605/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 610/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 615/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 620/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 625/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 630/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 635/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 640/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 645/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 650/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 655/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 660/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 665/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 670/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 675/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 680/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 685/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 690/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 695/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 700/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 705/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 710/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 715/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 720/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 725/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 730/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 735/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 740/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 745/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 750/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 755/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 760/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 765/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 770/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 775/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 780/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 785/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 790/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 795/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 800/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 805/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 810/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 815/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 820/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 825/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 830/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 835/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 840/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 845/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 850/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 855/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 860/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 865/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 870/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 875/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 880/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 885/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 890/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 895/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 900/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 905/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 910/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 915/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 920/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 925/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 930/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 935/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 940/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 945/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 950/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 955/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 960/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 965/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 970/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 975/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 980/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 985/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 990/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 995/1000, Train Loss: 0.0000, Test Loss: 0.0000
# Epoch 1000/1000, Train Loss: 0.0000, Test Loss: 0.0000

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = 0

while len(validation_predictions) < len(validation_target):
  input_ = X_test[i].reshape(1, T, 1)
  p = model(input_)[0,0].item() # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# last train input
# last_x = torch.from_numpy(X[-N//2]) # 1-D array of length T
# last_x = torch.from_numpy(X[-N//2].astype(np.float32))
last_x = X_test[0].view(T)

while len(validation_predictions) < len(validation_target):
  input_ = last_x.reshape(1, T, 1)
  p = model(input_)
  # [0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p[0,0].item())
  
  # make the new input
  last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
